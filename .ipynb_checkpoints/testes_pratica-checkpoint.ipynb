# %% [markdown]
# Um dos exemplos que foi mostrado no curso é do KNN

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia: {accuracy}")

plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, cmap='viridis', marker='o')
plt.title('Previsões do KNN')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# Acurácia: 1.0

# %% [markdown]
# Aqui está um exemplo de PCA, onde tentamos diminuir a quantidade de dimensões.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

iris = load_iris()
X = iris.data
y = iris.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(8, 6))
colors = ['r', 'g', 'b']
markers = ['o', 's', 'D']

for i, target_name in enumerate(iris.target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], 
                color=colors[i], marker=markers[i], label=target_name)

plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('PCA do Dataset Iris')
plt.legend()
plt.show()

print(f"Variância explicada pelo primeiro componente: {pca.explained_variance_ratio_[0]}")
print(f"Variância explicada pelo segundo componente: {pca.explained_variance_ratio_[1]}")
# Out:
# Variância explicada pelo primeiro componente: 0.7296244541329986
# Variância explicada pelo segundo componente: 0.22850761786701776

# %% [markdown]
# Retirada de outliers de um cojunto de dados

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
data = np.random.normal(50, 15, 1000) 
data = np.append(data, [150, 200, 250])  

Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

dados_sem_outliers = data[(data >= limite_inferior) & (data <= limite_superior)]

plt.hist(data, bins=30, edgecolor='k', alpha=0.7)
plt.title('Dados Originais')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.show()

plt.hist(dados_sem_outliers, bins=30, edgecolor='k', alpha=0.7)
plt.title('Dados Sem Outliers')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.show()
